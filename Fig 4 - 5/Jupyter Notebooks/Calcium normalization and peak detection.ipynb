# %% [markdown]
# ## This Jupyter Notebook extracts information about experimental conditions from image file names and creates inventories of image files and ROIs within each file for later data analysis
# ### Input:
# 1. csv files containing fluorescent values for each time point of individual images with names specifiying experimental specifications separated by "_";
# 2. csv file storing the specifications of each image file batch_df_name_copy.csv
# 3. csv file storing the list of each ROI within each image file
# ### Output:
# 1. Unormalized data with background-subtracted, bleedthrough corrected values with the following columns:
#    - Annotation columns (same as batch_df_name_copy.csv)
#    - Baseline
#    - Unormalized fluorescent values from time point 0 to 123.
# 3. Normalized data with dF/F values, a column of baseline values and a column of dF/F peak average.
#    - Annotation columns and Baseline same as above
#    - dF/F_Mean_p (for positive peaks) or dF/F_Mean_n (for negative peaks)
#    - Unormalized fluorescent values from time point 0 to 123.

# %% [markdown]
# ## Import packages and define functions
# Import necesssary packages and define the functions for normalization "norm()" and peak detection "find_peaks()"

# %%
#Import necessary packages
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

from math import nan
from typing import ClassVar, Type
from glob import glob
import pprint
import pylab as P
from tqdm import tqdm

# %%
#Get file directory
import os
from os import listdir
from os.path import isfile, join
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\fanr\\OneDrive - Max Planck Florida Institute for Neuroscience\\Codes\\mitoGCaMP\\manuscript'

# %%
#Specify the least number of time points in between peaks. For 0.3Hz & 0.2Hz stimulation protocols, INTER_PEAK_DISTANCE = 2
INTER_PEAK_DISTANCE = 2

#Specify the number of baseline timepoints
BS = 5

#Define function for normalization and peak detection

#Returns the normalized values (dF/F) of an array of time-lapse fluorescent value data 
def norm(arr):
    baseline = np.sum(arr[0:BS])/BS
    norm_arr = arr/baseline-1

    return norm_arr

#Detects peaks above threshold (2 times standard deviation of the baseline) in a normalized time-lapse fluorescent value data.
#Returns peak values and peak index.
def find_peaks(arr):
    global THRESHOLD_HEIGHT,INTER_PEAK_DISTANCE
    temp_peaks = []
    temp_peakcen = []
    real_peaks = []
    real_peakcen = []
    
    threshold = 2*np.std(arr[0:BS])
    arr = arr[~np.isnan(arr)]
    
    peak_one = 0
    for i in range(len(arr)):
        
        
        if i > BS-1 and i < len(arr)-1:
            if arr[i] > arr[i-1] and arr[i] > arr[i+1]:
                if peak_one == 0:
                    peak_one = i
                    temp_peakcen.append(i)
                    temp_peaks.append(arr[i])
                else:
                    if i - peak_one > INTER_PEAK_DISTANCE:
                        peak_one = i
                        temp_peakcen.append(i)
                        temp_peaks.append(arr[i])
                    elif arr[i] > arr[peak_one]:
                        peak_one = i
                        temp_peakcen.pop(-1)
                        temp_peaks.pop(-1)
                        temp_peakcen.append(i)
                        temp_peaks.append(arr[i])

    for i in range(len(temp_peaks)):
        if temp_peaks[i] > threshold:
            real_peaks.append(temp_peaks[i])
            real_peakcen.append(temp_peakcen[i])

    return [real_peaks, real_peakcen]

# %% [markdown]
# ## Import files

# %%
#import all files from the source folder
#mypath: path for source folder
mypath = ""

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles
# Out:
# ['052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCaMP_unc.csv',
#  '052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCaMP_myrCN27_unc.csv',
#  '052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCaMP_unc.csv']

# %%
#Specify batch, same as the prefix of output files from "Get_file_info"
batch = 'BATCH NAME'

# %%
#import name/selection files
df_name = pd.read_csv(batch+'_df_name_copy.csv')
selection =pd.read_csv(batch+'_selection.csv')

# %% [markdown]
# ## Combine data from all files to an unormalized summary data frame df0
# df0 will contain the annotating columns specified by the "batch_df_name_copy.csv", columns for channel and ROI name specified in "batch_selection.csv", and columns for background-subtracted fluoresent intensity values at each time point. The fluorescent intensity profile for each ROI of each channel under a specific condition is represented by one row.

# %%
df_unorm = []

ncol = 0
for i in onlyfiles:
    selection_i = selection[selection.File == i]
    selection_i2 = selection_i[selection_i['Selection']!='bg']
    df_name_i = df_name[df_name.File == i]
    
    df = pd.read_csv(mypath+'\\'+i)
    df = df.iloc[:,1:]
    
    
    
    for j in list(range(selection_i2.shape[0])):
        
        stim = selection_i2['Point'].iloc[j]
        channel = selection_i2['Channel'].iloc[j]
        select = selection_i2['Selection'].iloc[j]
       
        bg_arr = df[channel+"_"+str(stim)+"_bg"].values
        f_arr = df[channel+"_"+str(stim)+"_"+select].values      
        bg_subtract_arr = f_arr - bg_arr

        ncol = max(ncol,len(f_arr.tolist()))
        

        unorm_list = df_name_i.values.tolist()[0] + [stim]+[channel]+[select]+bg_subtract_arr.tolist()

        
        df_unorm = df_unorm+[unorm_list]
    

df0 = pd.DataFrame(df_unorm,columns =df_name.columns.to_list()+ ['Point','Channel','Selection'] + list(range(ncol)))



df0
# Out:
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# ..                                                ...    ...    ...    ...
# 91  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 92  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 93  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 94  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 95  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim              C1        C0 Treatment  Point Channel  ...      114  \
# 0      1  488mitoGCaMP6f  561RCaMP   myrCN27      1      C0  ...  127.375
# 1      1  488mitoGCaMP6f  561RCaMP   myrCN27      1      C1  ...    8.274
# 2      1  488mitoGCaMP6f  561RCaMP   myrCN27      1      C0  ...  202.972
# 3      1  488mitoGCaMP6f  561RCaMP   myrCN27      1      C1  ...   21.494
# 4      1  488mitoGCaMP6f  561RCaMP      ctrl      1      C0  ...  158.694
# ..   ...             ...       ...       ...    ...     ...  ...      ...
# 91     2  488mitoGCaMP6f  561RCaMP   myrCN27      1      C1  ...   99.669
# 92     2  488mitoGCaMP6f  561RCaMP      ctrl      1      C0  ...  295.091
# 93     2  488mitoGCaMP6f  561RCaMP      ctrl      1      C1  ...    8.220
# 94     2  488mitoGCaMP6f  561RCaMP      ctrl      1      C0  ...  428.353
# 95     2  488mitoGCaMP6f  561RCaMP      ctrl      1      C1  ...  145.708
#
#         115      116      117      118      119      120      121      122  \
# 0   100.607   94.382  170.324  127.481  108.759   99.500  166.572  129.498
# 1    -0.673   -2.087    0.492    0.404   -0.371    3.074   -2.751    2.110
# 2   168.880  143.564  248.077  202.493  158.339  160.682  270.351  201.606
# 3    20.426   19.793   21.349   16.880   12.265   24.575   23.399   21.284
# 4   138.287  102.575  188.079  149.673  130.428  115.256  193.885  176.759
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 91   94.664   84.893   92.195   85.575   88.943   83.862   99.535  123.782
# 92  217.760  207.677  468.865  271.883  194.855  161.510  444.996  265.756
# 93    4.775    0.022   13.896    6.062    3.889    1.764   15.100    6.235
# 94  320.923  286.189  672.683  497.490  353.113  287.700  593.087  416.951
# 95  144.942  146.094  157.456  149.201  138.604  138.276  150.386  132.553
#
#         123
# 0   108.654
# 1     2.002
# 2   159.992
# 3    17.509
# 4   131.948
# ..      ...
# 91  118.838
# 92  179.755
# 93    2.193
# 94  314.386
# 95  128.372
#
# [96 rows x 135 columns]

# %% [markdown]
# ## Correcting bleedthrough
# The percentage of bleedthrough from 561 channel to 488 channel with the same imaging setting has been measured to be 0.57%. This amount is subtracted from the images before further analysis. Bleedtrough-corrected values are added as additional rows named "C1_correct".

# %%
#Create a dataframe "df0_correct" containing the C1 (488) bleedthrough-corrected values
df0 = df0.drop(columns = ['C0','C1'])
df0_C0 = df0[df0['Channel']=='C0'].drop(columns=['Channel'])
df0_C1 = df0[df0['Channel']=='C1'].drop(columns=['Channel'])

df0_rearrange = df0_C0.merge(df0_C1, on =[   'File',    'Date', 'Dish',      'Cell','Stim','Treatment', 'Point',
       'Selection'],how = 'outer',suffixes = ['_C0','_C1'])


for i in range(0,124):
    df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057

col = list(df0_rearrange.columns[8:256])
df0_correct = df0_rearrange.drop(columns = col)

df0_correct['Channel']=['C1_correct']*df0_correct.shape[0]
df0_correct = df0_correct[[  'File',    'Date',     'Dish',      'Cell','Stim','Treatment','Point','Channel', 'Selection']+list(df0_correct.columns[8:132])]

df0_correct
# Out:
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_rearrange[str(i)+'_C1_correct'] = df0_rearrange[str(i)+'_C1']-df0_rearrange[str(i)+'_C0']*0.0057
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\509102770.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0_correct['Channel']=['C1_correct']*df0_correct.shape[0]
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 5   052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 6   052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 7   052625_dish1_cell1_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 8   052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 9   052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 10  052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 11  052625_dish1_cell2_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 12  052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 13  052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 14  052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 15  052625_dish1_cell2_stim3_488mitoGCaMP6f_561RCa...  52625  dish1  cell2
# 16  052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 17  052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 18  052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 19  052625_dish1_cell3_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 20  052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 21  052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 22  052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 23  052625_dish1_cell3_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell3
# 24  052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 25  052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 26  052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 27  052625_dish1_cell4_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 28  052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 29  052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 30  052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 31  052625_dish1_cell4_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell4
# 32  052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 33  052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 34  052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 35  052625_dish1_cell5_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 36  052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 37  052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 38  052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 39  052625_dish1_cell5_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell5
# 40  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 41  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 42  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 43  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 44  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 45  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 46  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 47  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim Treatment  Point     Channel Selection  0_C1_correct  ...  \
# 0      1   myrCN27      1  C1_correct        sp     -3.003996  ...
# 1      1   myrCN27      1  C1_correct      stim     19.055729  ...
# 2      1      ctrl      1  C1_correct        sp      1.103063  ...
# 3      1      ctrl      1  C1_correct      stim      7.776503  ...
# 4      2   myrCN27      1  C1_correct        sp      3.452827  ...
# 5      2   myrCN27      1  C1_correct      stim     15.778655  ...
# 6      2      ctrl      1  C1_correct        sp      5.430585  ...
# 7      2      ctrl      1  C1_correct      stim     18.700661  ...
# 8      1   myrCN27      1  C1_correct        sp     -2.018660  ...
# 9      1   myrCN27      1  C1_correct      stim     14.010918  ...
# 10     1      ctrl      1  C1_correct        sp     -0.488051  ...
# 11     1      ctrl      1  C1_correct      stim     32.383547  ...
# 12     3   myrCN27      1  C1_correct        sp      0.183488  ...
# 13     3   myrCN27      1  C1_correct      stim     10.824441  ...
# 14     3      ctrl      1  C1_correct        sp      5.115436  ...
# 15     3      ctrl      1  C1_correct      stim     22.081916  ...
# 16     1   myrCN27      1  C1_correct        sp      0.909808  ...
# 17     1   myrCN27      1  C1_correct      stim     29.619839  ...
# 18     1      ctrl      1  C1_correct        sp      2.930127  ...
# 19     1      ctrl      1  C1_correct      stim     19.693507  ...
# 20     2   myrCN27      1  C1_correct        sp      1.001693  ...
# 21     2   myrCN27      1  C1_correct      stim     15.937369  ...
# 22     2      ctrl      1  C1_correct        sp     -3.018991  ...
# 23     2      ctrl      1  C1_correct      stim     38.524796  ...
# 24     1   myrCN27      1  C1_correct        sp      2.580107  ...
# 25     1   myrCN27      1  C1_correct      stim     24.020287  ...
# 26     1      ctrl      1  C1_correct        sp      3.133616  ...
# 27     1      ctrl      1  C1_correct      stim     28.244996  ...
# 28     2   myrCN27      1  C1_correct        sp     -1.295489  ...
# 29     2   myrCN27      1  C1_correct      stim     37.012243  ...
# 30     2      ctrl      1  C1_correct        sp      0.689483  ...
# 31     2      ctrl      1  C1_correct      stim     26.554777  ...
# 32     1   myrCN27      1  C1_correct        sp     -0.322367  ...
# 33     1   myrCN27      1  C1_correct      stim     28.983216  ...
# 34     1      ctrl      1  C1_correct        sp      3.754423  ...
# 35     1      ctrl      1  C1_correct      stim     27.718876  ...
# 36     2   myrCN27      1  C1_correct        sp     -0.004400  ...
# 37     2   myrCN27      1  C1_correct      stim     29.560396  ...
# 38     2      ctrl      1  C1_correct        sp      2.964650  ...
# 39     2      ctrl      1  C1_correct      stim     33.576620  ...
# 40     1   myrCN27      1  C1_correct        sp      6.805418  ...
# 41     1   myrCN27      1  C1_correct      stim     15.991258  ...
# 42     1      ctrl      1  C1_correct        sp     -1.154088  ...
# 43     1      ctrl      1  C1_correct      stim     16.661540  ...
# 44     2   myrCN27      1  C1_correct        sp     -2.665894  ...
# 45     2   myrCN27      1  C1_correct      stim     22.345828  ...
# 46     2      ctrl      1  C1_correct        sp      3.299147  ...
# 47     2      ctrl      1  C1_correct      stim     21.776667  ...
#
#     114_C1_correct  115_C1_correct  116_C1_correct  117_C1_correct  \
# 0         7.547963       -1.246460       -2.624977       -0.478847
# 1        20.337060       19.463384       18.974685       19.934961
# 2         0.721444        5.045764        6.719322        1.126950
# 3        14.500425        8.879116       10.066120       11.694554
# 4         0.195066        6.207745       -0.551168        9.059663
# 5       109.642237      103.161922       98.660514      104.797758
# 6         3.380802        2.841811        7.508979        4.854083
# 7        97.784364       96.081665       94.759731       95.241863
# 8         5.827324       -1.018460       -0.439438        1.892954
# 9        28.652034       25.503533       27.879262       24.519560
# 10        1.502418        7.900592        5.813753        8.506409
# 11       91.959311       84.677903       86.067571       73.054237
# 12        6.838762        6.358954       -1.538744       11.429343
# 13       54.019692       43.947400       48.364380       47.056266
# 14        9.287102        6.490524        1.229371        0.949665
# 15       70.756893       66.612674       73.129238       78.876661
# 16       -0.896298       -2.035710       -4.962821        3.241946
# 17      100.615817       87.047880       87.200970       99.671757
# 18        1.317213        0.461669        2.755320        2.548710
# 19       70.070623       67.420941       58.620057       64.149072
# 20        3.000834        3.307102        3.723685        3.589396
# 21       85.626986       82.964120       72.175892       83.720719
# 22        5.120897        1.301223        3.166707        7.109720
# 23       69.006384       65.992808       60.619542       64.846322
# 24        7.953059        4.154826        2.953753       20.511025
# 25       69.072192       67.394149       71.229163       71.482870
# 26       -1.416396        1.889517        5.048261        7.529808
# 27      103.038582       94.469547       88.225022      101.931900
# 28        4.175657        2.829410        2.614105       13.871939
# 29      123.344526      117.392007      128.567940      123.457946
# 30       11.657517        5.396748        5.206217       18.019373
# 31      146.902427      137.472833      145.410627      155.632651
# 32        4.708803        7.303020        6.071947       16.513289
# 33      115.683825      104.374877      112.450176      120.448523
# 34       10.510851        8.882587        0.974972        8.222495
# 35      134.551150      125.311446      129.750429      131.560345
# 36        4.433253        1.604945       -3.388572       13.210345
# 37      104.022287      112.780795      107.891272      107.199096
# 38       -0.122635       -2.782654        5.005960       11.457378
# 39      103.453164      105.363618      103.902092      102.076663
# 40        1.617373       -1.324335       -2.887458        1.970283
# 41       46.958664       39.468146       35.468186       54.196649
# 42        1.954241        5.427891        5.729578        5.326018
# 43       71.448396       66.407014       62.533867       78.663016
# 44       13.491168        9.715104        1.144497       10.650109
# 45       98.178883       93.326980       83.715483       90.620535
# 46        6.537981        3.533768       -1.161759       11.223470
# 47      143.266388      143.112739      144.462723      153.621707
#
#     118_C1_correct  119_C1_correct  120_C1_correct  121_C1_correct  \
# 0        -0.322642       -0.990926        2.506850       -3.700460
# 1        15.725790       11.362468       23.659113       21.857999
# 2         2.086864       -5.412440        4.080041       -0.228144
# 3        14.159679       10.877237        9.962066       14.355455
# 4        -1.829180        4.820443        0.170348        1.110632
# 5       111.034006       91.875026      100.149420      111.206281
# 6         3.172012        6.417098        7.683265        1.727858
# 7       101.730134       90.848496       93.876478       94.710003
# 8        -1.210547        6.553121        4.003837        0.042018
# 9        24.070426       29.282390       25.335876       27.937904
# 10        3.447470        6.338020        1.613958       11.189315
# 11       79.206932       77.245089       66.614399       84.489929
# 12       12.398841        8.316426        8.964084       20.322142
# 13       50.180275       52.214739       51.660921       51.981534
# 14        9.257144       12.983909        1.988147        2.690640
# 15       71.889402       65.235394       70.586508       71.160153
# 16        4.027547        2.323466        2.888256        1.465207
# 17       95.324490       91.493963       90.788197      105.500577
# 18       -2.124280        0.502045       -1.759811        0.811922
# 19       61.195630       57.859733       53.775482       65.691383
# 20        4.184385        4.905594        0.379421        4.306932
# 21       83.638584       75.849068       75.554793       76.307315
# 22       -0.436615        1.569220       -0.494709        5.731265
# 23       64.307515       64.618748       57.730194       67.987186
# 24       13.202790        9.604283       -1.148188        7.147894
# 25       70.568450       66.655620       60.881854       66.904338
# 26       11.288119        9.173564        7.651297       10.330533
# 27       97.656781       96.732714       94.323398      100.832586
# 28        7.391785        2.597460        3.261087        4.986112
# 29      124.077374      126.374413      121.234578      133.495083
# 30       11.764461        9.461457        0.350275       19.670020
# 31      153.248362      137.897860      138.481317      156.282382
# 32        8.969338        7.512805        2.989104       17.083979
# 33      110.210785      107.733888      107.808053      113.356973
# 34        5.947689        8.269810       -0.200623        2.814115
# 35      138.877632      130.779713      136.162191      136.616328
# 36       13.775901       11.768874        2.629643       22.345052
# 37      101.598314      101.960847      104.914523      106.156363
# 38        7.074487        4.298933        2.031733        9.907502
# 39      107.776983       97.852195      103.575660      106.309558
# 40        0.423487        1.642389        0.838916        0.966750
# 41       42.219089       39.811409       43.598272       49.033407
# 42       13.264989        2.642897       -1.722372        6.039133
# 43       74.185153       68.061440       61.319028       71.418889
# 44        3.484582        3.229086       -2.634690       17.235059
# 45       84.218782       87.627412       82.560867       97.346006
# 46        4.512267        2.778327        0.843393       12.563523
# 47      146.365307      136.591256      136.636110      147.005404
#
#     122_C1_correct  123_C1_correct
# 0         1.371861        1.382672
# 1        20.134846       16.597046
# 2         3.400474        3.941896
# 3        10.910059        9.977570
# 4         8.262192        4.323084
# 5       107.793678       96.060485
# 6         1.807715        3.402451
# 7       102.347238       97.884125
# 8         3.249642        2.852410
# 9        28.570824       29.492711
# 10        9.889421        0.847572
# 11       88.844313       78.182775
# 12        3.423376        0.579021
# 13       50.083062       56.004685
# 14       14.661303        4.012417
# 15       67.172933       71.079981
# 16        8.753594       -0.194464
# 17       90.089554       94.908559
# 18        2.281521        2.438205
# 19       61.587579       53.880043
# 20        4.671571        7.426170
# 21       81.874776       75.014022
# 22        4.743955        1.641800
# 23       64.361640       68.269808
# 24        7.237091        8.802437
# 25       69.804240       63.115518
# 26        7.842946        7.251348
# 27      102.436254      101.223342
# 28       10.131480        4.874896
# 29      128.683367      121.192021
# 30       13.907829        7.189336
# 31      151.456878      138.459951
# 32       16.218679        4.740795
# 33      106.265361      101.950942
# 34        8.600935        9.376358
# 35      129.939366      129.607618
# 36        7.235640        5.402380
# 37      110.886065      101.705551
# 38       11.509249        7.639039
# 39      112.667711      106.797991
# 40        4.033514        0.987506
# 41       44.562874       43.023616
# 42        8.889828        1.364145
# 43       73.224165       70.011097
# 44        5.759455       -2.579988
# 45      122.169960      117.428761
# 46        4.720191        1.168396
# 47      130.176379      126.580000
#
# [48 rows x 133 columns]

# %%
# Add the bleedthrough-corrected data into the main dataframe df0
df0_correct.columns = [  'File',    'Date', 'Dish',      'Cell','Stim','Treatment','Point','Channel', 'Selection' ]+list(df0.columns[9:])
df0 = pd.concat([df0,df0_correct],axis=0)
df0.replace(0, np.nan, inplace=True)
df0
# Out:
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# ..                                                ...    ...    ...    ...
# 43  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 44  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 45  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 46  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 47  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim Treatment  Point     Channel Selection           0  ...         114  \
# 0      1   myrCN27      1          C0        sp   45.087000  ...  127.375000
# 1      1   myrCN27      1          C1        sp   -2.747000  ...    8.274000
# 2      1   myrCN27      1          C0      stim  148.644000  ...  202.972000
# 3      1   myrCN27      1          C1      stim   19.903000  ...   21.494000
# 4      1      ctrl      1          C0        sp   49.989000  ...  158.694000
# ..   ...       ...    ...         ...       ...         ...  ...         ...
# 43     1      ctrl      1  C1_correct      stim   16.661540  ...   71.448396
# 44     2   myrCN27      1  C1_correct        sp   -2.665894  ...   13.491168
# 45     2   myrCN27      1  C1_correct      stim   22.345828  ...   98.178883
# 46     2      ctrl      1  C1_correct        sp    3.299147  ...    6.537981
# 47     2      ctrl      1  C1_correct      stim   21.776667  ...  143.266388
#
#            115         116         117         118         119         120  \
# 0   100.607000   94.382000  170.324000  127.481000  108.759000   99.500000
# 1    -0.673000   -2.087000    0.492000    0.404000   -0.371000    3.074000
# 2   168.880000  143.564000  248.077000  202.493000  158.339000  160.682000
# 3    20.426000   19.793000   21.349000   16.880000   12.265000   24.575000
# 4   138.287000  102.575000  188.079000  149.673000  130.428000  115.256000
# ..         ...         ...         ...         ...         ...         ...
# 43   66.407014   62.533867   78.663016   74.185153   68.061440   61.319028
# 44    9.715104    1.144497   10.650109    3.484582    3.229086   -2.634690
# 45   93.326980   83.715483   90.620535   84.218782   87.627412   82.560867
# 46    3.533768   -1.161759   11.223470    4.512267    2.778327    0.843393
# 47  143.112739  144.462723  153.621707  146.365307  136.591256  136.636110
#
#            121         122         123
# 0   166.572000  129.498000  108.654000
# 1    -2.751000    2.110000    2.002000
# 2   270.351000  201.606000  159.992000
# 3    23.399000   21.284000   17.509000
# 4   193.885000  176.759000  131.948000
# ..         ...         ...         ...
# 43   71.418889   73.224165   70.011097
# 44   17.235059    5.759455   -2.579988
# 45   97.346006  122.169960  117.428761
# 46   12.563523    4.720191    1.168396
# 47  147.005404  130.176379  126.580000
#
# [144 rows x 133 columns]

# %% [markdown]
# ## Calculate & Rearrange Baseline
# Calculate the baseline value before stimulation for dF/F analysis in the "normalization" section. For ERGCaMP experiments, the ERGCaMP signal has been observed to have an initial photo-bleaching phase. Therefore, 15 baseline time points were acquired as prior to stimulation but only the last 5 time points were averaged to get the baseline value.

# %%
t0 = 9 #The start of the baseline
t1 = 14 #The end of the baseline



df0.iloc[:,t0:t1].dropna(axis=1,inplace=True)
df0['Baseline'] = df0.iloc[:,t0:t1].apply(np.mean,axis=1)
cols = list(df0)
cols.insert(t0, cols.pop(cols.index('Baseline')))
df0 = df0.loc[:, cols]

df0
# Out:
# C:\Users\fanr\AppData\Local\Temp\ipykernel_21444\3079362692.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df0['Baseline'] = df0.iloc[:,t0:t1].apply(np.mean,axis=1)
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# ..                                                ...    ...    ...    ...
# 43  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 44  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 45  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 46  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 47  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim Treatment  Point     Channel Selection    Baseline  ...         114  \
# 0      1   myrCN27      1          C0        sp   50.036400  ...  127.375000
# 1      1   myrCN27      1          C1        sp   -1.120200  ...    8.274000
# 2      1   myrCN27      1          C0      stim  158.863600  ...  202.972000
# 3      1   myrCN27      1          C1      stim   19.746000  ...   21.494000
# 4      1      ctrl      1          C0        sp   53.829800  ...  158.694000
# ..   ...       ...    ...         ...       ...         ...  ...         ...
# 43     1      ctrl      1  C1_correct      stim   17.508097  ...   71.448396
# 44     2   myrCN27      1  C1_correct        sp    2.920524  ...   13.491168
# 45     2   myrCN27      1  C1_correct      stim   23.141075  ...   98.178883
# 46     2      ctrl      1  C1_correct        sp    1.388332  ...    6.537981
# 47     2      ctrl      1  C1_correct      stim   24.396539  ...  143.266388
#
#            115         116         117         118         119         120  \
# 0   100.607000   94.382000  170.324000  127.481000  108.759000   99.500000
# 1    -0.673000   -2.087000    0.492000    0.404000   -0.371000    3.074000
# 2   168.880000  143.564000  248.077000  202.493000  158.339000  160.682000
# 3    20.426000   19.793000   21.349000   16.880000   12.265000   24.575000
# 4   138.287000  102.575000  188.079000  149.673000  130.428000  115.256000
# ..         ...         ...         ...         ...         ...         ...
# 43   66.407014   62.533867   78.663016   74.185153   68.061440   61.319028
# 44    9.715104    1.144497   10.650109    3.484582    3.229086   -2.634690
# 45   93.326980   83.715483   90.620535   84.218782   87.627412   82.560867
# 46    3.533768   -1.161759   11.223470    4.512267    2.778327    0.843393
# 47  143.112739  144.462723  153.621707  146.365307  136.591256  136.636110
#
#            121         122         123
# 0   166.572000  129.498000  108.654000
# 1    -2.751000    2.110000    2.002000
# 2   270.351000  201.606000  159.992000
# 3    23.399000   21.284000   17.509000
# 4   193.885000  176.759000  131.948000
# ..         ...         ...         ...
# 43   71.418889   73.224165   70.011097
# 44   17.235059    5.759455   -2.579988
# 45   97.346006  122.169960  117.428761
# 46   12.563523    4.720191    1.168396
# 47  147.005404  130.176379  126.580000
#
# [144 rows x 134 columns]

# %%
# save unormalized data
df0.to_csv(batch + "_unorm.csv",index=False)

# %% [markdown]
# ## Normalization
# To normalize the data with the baseline values using the formula of dF/F = (F-F0)/F0, where F is the fluorescent value at each time point, and F0 is the baseline value calculated earlier. For ERGCaMP experiments, the first 10 time points are removed from the normalized dataset.

# %%
# For mitoGCaMP and RCaMP analysis
c = 10 # Number of columns including Baseline column
df_norm = pd.concat([df0.iloc[:,0:c],df0.iloc[:,c:].apply(norm,axis=1)],axis = 1)
df_norm
# Out:
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# ..                                                ...    ...    ...    ...
# 43  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 44  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 45  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 46  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 47  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim Treatment  Point     Channel Selection    Baseline  ...       114  \
# 0      1   myrCN27      1          C0        sp   50.036400  ...  1.545647
# 1      1   myrCN27      1          C1        sp   -1.120200  ... -8.386181
# 2      1   myrCN27      1          C0      stim  158.863600  ...  0.277650
# 3      1   myrCN27      1          C1      stim   19.746000  ...  0.088524
# 4      1      ctrl      1          C0        sp   53.829800  ...  1.948070
# ..   ...       ...    ...         ...       ...         ...  ...       ...
# 43     1      ctrl      1  C1_correct      stim   17.508097  ...  3.080877
# 44     2   myrCN27      1  C1_correct        sp    2.920524  ...  3.619433
# 45     2   myrCN27      1  C1_correct      stim   23.141075  ...  3.242624
# 46     2      ctrl      1  C1_correct        sp    1.388332  ...  3.709234
# 47     2      ctrl      1  C1_correct      stim   24.396539  ...  4.872406
#
#          115       116       117       118       119       120       121  \
# 0   1.010676  0.886267  2.404002  1.547765  1.173598  0.988552  2.329016
# 1  -0.399214  0.863060 -1.439207 -1.360650 -0.668809 -3.744153  1.455811
# 2   0.063050 -0.096307  0.561572  0.274634 -0.003302  0.011446  0.701781
# 3   0.034437  0.002380  0.081181 -0.145143 -0.378862  0.244556  0.184999
# 4   1.568967  0.905543  2.493957  1.780486  1.422970  1.141119  2.601815
# ..       ...       ...       ...       ...       ...       ...       ...
# 43  2.792932  2.571711  3.492951  3.237191  2.887427  2.502324  3.079192
# 44  2.326493 -0.608119  2.646642  0.193136  0.105653 -1.902129  4.901357
# 45  3.032958  2.617614  2.916004  2.639363  2.786661  2.567720  3.206633
# 46  1.545333 -1.836802  7.084137  2.250135  1.001197 -0.392514  8.049363
# 47  4.866108  4.921443  5.296865  4.999429  4.598796  4.600635  5.025666
#
#          122       123
# 0   1.588076  1.171499
# 1  -2.883592 -2.787181
# 2   0.269051  0.007103
# 3   0.077889 -0.113289
# 4   2.283664  1.451207
# ..       ...       ...
# 43  3.182303  2.998784
# 44  0.972062 -1.883399
# 45  4.279355  4.074473
# 46  2.399900 -0.158417
# 47  4.335854  4.188441
#
# [144 rows x 134 columns]

# %%
# For ERGCaMP: remove 10 baselines
c=12 # Number of columns including Baseline column
c1 = 22 # c + (number of baseline timepoints to be removed)
df_norm = pd.concat([df0.iloc[:,0:c],df0.iloc[:,c1:].apply(norm,axis=1)],axis = 1)

df_norm.columns=list(df_norm.columns[0:12]) +list(range(50))

df_norm
# Out:
#                                                  File    Date   Dish   Cell  \
# 0   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 1   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 2   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 3   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 4   110924_dish1_cell1_stim2_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# ..                                                ...     ...    ...    ...
# 69  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 70  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 71  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 72  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 73  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
#
#     Stim1          C1         C0 Treatment  Replicate Channel  ...        40  \
# 0       1  488ERGCaMP  561PSDmCh      ctrl          0      C0  ... -0.959046
# 1       1  488ERGCaMP  561PSDmCh      ctrl          0      C1  ... -0.059735
# 2       1  488ERGCaMP  561PSDmCh      2APB          0      C0  ...  1.119597
# 3       1  488ERGCaMP  561PSDmCh      2APB          0      C1  ... -0.051437
# 4       2  488ERGCaMP  561PSDmCh      ctrl          0      C0  ... -1.259509
# ..    ...         ...        ...       ...        ...     ...  ...       ...
# 69      3  488ERGCaMP  561PSDmCh      ctrl          0      C1  ... -0.221111
# 70      3  488ERGCaMP  561PSDmCh      2APB          1      C0  ... -3.642183
# 71      3  488ERGCaMP  561PSDmCh      2APB          1      C1  ... -0.258938
# 72      3  488ERGCaMP  561PSDmCh      2APB          2      C0  ... -6.573770
# 73      3  488ERGCaMP  561PSDmCh      2APB          2      C1  ... -0.296808
#
#            41        42        43         44         45         46         47  \
# 0   -0.706571 -0.274227 -0.356586   0.058056  -0.180018   0.436544  -0.462646
# 1   -0.039983 -0.056874 -0.033314  -0.040394  -0.040454  -0.051630  -0.072988
# 2    0.415710  1.291487  0.405959   0.814141   0.092567  -0.512903  -0.230577
# 3    0.014318 -0.045588  0.058842   0.030833  -0.048681   0.024859   0.058072
# 4   -0.157232  0.215494 -2.232668   4.636687   0.901158  -0.429462  -1.276046
# ..        ...       ...       ...        ...        ...        ...        ...
# 69  -0.345809 -0.233818 -0.172668  -0.118316  -0.218189  -0.175177  -0.044730
# 70  -3.529906 -4.927597 -8.055614   3.271773  -2.076600  -5.605456  -4.485834
# 71  -0.675583 -0.428827 -0.338593  -0.398865  -0.336091  -0.471077  -0.296089
# 72 -29.401639  5.204918  2.639344  46.295082 -13.000000 -38.344262  60.229508
# 73  -0.154389 -0.513288 -0.353113  -0.309377  -0.567438  -0.384517  -0.366959
#
#            48         49
# 0    0.392739  -0.905941
# 1   -0.070390  -0.031004
# 2    0.670824  -0.204272
# 3    0.122229   0.141520
# 4    0.825467   0.857906
# ..        ...        ...
# 69  -0.179450  -0.153576
# 70  -3.369360  -0.611752
# 71  -0.350217  -0.582119
# 72  11.590164  58.114754
# 73  -0.259577  -0.462729
#
# [74 rows x 62 columns]

# %% [markdown]
# ## Find peaks - Positive peaks
# For MitoGCaMP and RCaMP analysis, average the first 10 peaks detected using the "find_peaks" function and add a column after the baseline column.

# %%
c = 10 # Number of columns including Baseline
unc = 10 # Number of peaks to be averaged.

df_norm['dF/F_Mean_p'] = (df_norm.iloc[:,c:]).apply(find_peaks,axis=1, result_type='expand')[0].apply(lambda x: np.mean(x[0:unc]))


df_norm = df_norm.fillna(0)

cols = list(df_norm)
cols.insert(c, cols.pop(cols.index('dF/F_Mean_p')))
df_norm = df_norm.loc[:, cols]


df_norm
# Out:
# C:\Users\fanr\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fanr\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#                                                  File   Date   Dish   Cell  \
# 0   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 1   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 2   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 3   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# 4   052625_dish1_cell1_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell1
# ..                                                ...    ...    ...    ...
# 43  052625_dish1_cell6_stim1_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 44  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 45  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 46  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
# 47  052625_dish1_cell6_stim2_488mitoGCaMP6f_561RCa...  52625  dish1  cell6
#
#     Stim Treatment  Point     Channel Selection    Baseline  ...       114  \
# 0      1   myrCN27      1          C0        sp   50.036400  ...  1.545647
# 1      1   myrCN27      1          C1        sp   -1.120200  ... -8.386181
# 2      1   myrCN27      1          C0      stim  158.863600  ...  0.277650
# 3      1   myrCN27      1          C1      stim   19.746000  ...  0.088524
# 4      1      ctrl      1          C0        sp   53.829800  ...  1.948070
# ..   ...       ...    ...         ...       ...         ...  ...       ...
# 43     1      ctrl      1  C1_correct      stim   17.508097  ...  3.080877
# 44     2   myrCN27      1  C1_correct        sp    2.920524  ...  3.619433
# 45     2   myrCN27      1  C1_correct      stim   23.141075  ...  3.242624
# 46     2      ctrl      1  C1_correct        sp    1.388332  ...  3.709234
# 47     2      ctrl      1  C1_correct      stim   24.396539  ...  4.872406
#
#          115       116       117       118       119       120       121  \
# 0   1.010676  0.886267  2.404002  1.547765  1.173598  0.988552  2.329016
# 1  -0.399214  0.863060 -1.439207 -1.360650 -0.668809 -3.744153  1.455811
# 2   0.063050 -0.096307  0.561572  0.274634 -0.003302  0.011446  0.701781
# 3   0.034437  0.002380  0.081181 -0.145143 -0.378862  0.244556  0.184999
# 4   1.568967  0.905543  2.493957  1.780486  1.422970  1.141119  2.601815
# ..       ...       ...       ...       ...       ...       ...       ...
# 43  2.792932  2.571711  3.492951  3.237191  2.887427  2.502324  3.079192
# 44  2.326493 -0.608119  2.646642  0.193136  0.105653 -1.902129  4.901357
# 45  3.032958  2.617614  2.916004  2.639363  2.786661  2.567720  3.206633
# 46  1.545333 -1.836802  7.084137  2.250135  1.001197 -0.392514  8.049363
# 47  4.866108  4.921443  5.296865  4.999429  4.598796  4.600635  5.025666
#
#          122       123
# 0   1.588076  1.171499
# 1  -2.883592 -2.787181
# 2   0.269051  0.007103
# 3   0.077889 -0.113289
# 4   2.283664  1.451207
# ..       ...       ...
# 43  3.182303  2.998784
# 44  0.972062 -1.883399
# 45  4.279355  4.074473
# 46  2.399900 -0.158417
# 47  4.335854  4.188441
#
# [144 rows x 135 columns]

# %% [markdown]
# ## Peak finding - Negative peaks
# For ERGCaMP analysis, average the 6 inverse peaks and add one column after the baseline column.

# %%
c = 12 # Number of columns including Baseline
unc = 6 # Number of peaks to be averaged.

df_norm['Mean_n'] = -(-df_norm.iloc[:,c:]).apply(find_peaks,axis=1, result_type='expand')[0].apply(lambda x: np.mean(x[0:unc]))
df_norm = df_norm.fillna(0)

cols = list(df_norm)
cols.insert(c, cols.pop(cols.index('Mean_n')))
df_norm = df_norm.loc[:, cols]

df_norm
# Out:
# C:\Users\fanr\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fanr\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#                                                  File    Date   Dish   Cell  \
# 0   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 1   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 2   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 3   110924_dish1_cell1_stim1_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# 4   110924_dish1_cell1_stim2_488ERGCaMP_561PSDmCh_...  110924  dish1  cell1
# ..                                                ...     ...    ...    ...
# 69  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 70  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 71  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 72  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
# 73  111224_dish1_cell2_stim3_488ERGCaMP_561PSDmCh_...  111224  dish1  cell2
#
#     Stim1          C1         C0 Treatment  Replicate Channel  ...        40  \
# 0       1  488ERGCaMP  561PSDmCh      ctrl          0      C0  ... -0.959046
# 1       1  488ERGCaMP  561PSDmCh      ctrl          0      C1  ... -0.059735
# 2       1  488ERGCaMP  561PSDmCh      2APB          0      C0  ...  1.119597
# 3       1  488ERGCaMP  561PSDmCh      2APB          0      C1  ... -0.051437
# 4       2  488ERGCaMP  561PSDmCh      ctrl          0      C0  ... -1.259509
# ..    ...         ...        ...       ...        ...     ...  ...       ...
# 69      3  488ERGCaMP  561PSDmCh      ctrl          0      C1  ... -0.221111
# 70      3  488ERGCaMP  561PSDmCh      2APB          1      C0  ... -3.642183
# 71      3  488ERGCaMP  561PSDmCh      2APB          1      C1  ... -0.258938
# 72      3  488ERGCaMP  561PSDmCh      2APB          2      C0  ... -6.573770
# 73      3  488ERGCaMP  561PSDmCh      2APB          2      C1  ... -0.296808
#
#            41        42        43         44         45         46         47  \
# 0   -0.706571 -0.274227 -0.356586   0.058056  -0.180018   0.436544  -0.462646
# 1   -0.039983 -0.056874 -0.033314  -0.040394  -0.040454  -0.051630  -0.072988
# 2    0.415710  1.291487  0.405959   0.814141   0.092567  -0.512903  -0.230577
# 3    0.014318 -0.045588  0.058842   0.030833  -0.048681   0.024859   0.058072
# 4   -0.157232  0.215494 -2.232668   4.636687   0.901158  -0.429462  -1.276046
# ..        ...       ...       ...        ...        ...        ...        ...
# 69  -0.345809 -0.233818 -0.172668  -0.118316  -0.218189  -0.175177  -0.044730
# 70  -3.529906 -4.927597 -8.055614   3.271773  -2.076600  -5.605456  -4.485834
# 71  -0.675583 -0.428827 -0.338593  -0.398865  -0.336091  -0.471077  -0.296089
# 72 -29.401639  5.204918  2.639344  46.295082 -13.000000 -38.344262  60.229508
# 73  -0.154389 -0.513288 -0.353113  -0.309377  -0.567438  -0.384517  -0.366959
#
#            48         49
# 0    0.392739  -0.905941
# 1   -0.070390  -0.031004
# 2    0.670824  -0.204272
# 3    0.122229   0.141520
# 4    0.825467   0.857906
# ..        ...        ...
# 69  -0.179450  -0.153576
# 70  -3.369360  -0.611752
# 71  -0.350217  -0.582119
# 72  11.590164  58.114754
# 73  -0.259577  -0.462729
#
# [74 rows x 63 columns]

# %% [markdown]
# ## Save the normalized dataframe

# %%
df_norm.to_csv(batch+'_norm.csv',index=False)
